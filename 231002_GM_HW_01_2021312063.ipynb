# %% [markdown]
# # Graph Mining HW 01 (231002)
# - [수행내용] 실제 데이터를 활용해 그래프를 생성하고, 이를 Gephi를 이용해 시각화할 것.
# - [데이터셋] vivino 와인 리뷰 데이터
# - [제출파일]: 해당 파일 내 코드 및 답변을 추가한 ipynb 파일 (hw01_학번+이름.ipynb)
# - [제출기한] 10월 15일 23:59까지
# - [유의사항]
#   1. 제출 파일 형식에 맞춰 결과물을 정확히 제출할 것.
#   2. 제출 기한을 엄수할 것.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Environment Setting

# %%
import pandas as pd
import networkx as nx

# %% [markdown]
# # 2. Load Dataset

# %%
# load dataset
'''
wine = pd.read_csv('./wine_info.csv')
user = pd.read_csv('./user_info.csv')
review = pd.read_csv('./review.csv')
'''
review = pd.read_csv('/content/drive/MyDrive/SKKU3-2_DM/HW1/vivino/review.csv')
user = pd.read_csv('/content/drive/MyDrive/SKKU3-2_DM/HW1/vivino/user_info.csv')
wine = pd.read_csv('/content/drive/MyDrive/SKKU3-2_DM/HW1/vivino/wine_info.csv')

# %%
'''
     [Wine Table : wine information]

1. wid : wine_id
2. name : wine_name
3. vintage : wine_vintage
4. winery : winery_name
5. avg_ratings : 해당 와인에 대한 평균 평점
6. num_ratings : 해당 와인에 대한 리뷰 개수
7. foods : 해당 와인과 잘 어울리는 음식

'''
wine
# Out:
#         wid                                               name vintage  \
# 0        w0      Clos d'Ambonnay Blanc de Noirs Brut Champagne    1995
# 1        w1                       The Beast Cabernet Sauvignon    2017
# 2        w2         Château Margaux (Premier Grand Cru Classé)    2018
# 3        w3                              Vintage Port Nacional    1994
# 4        w4      Grand Vin Pauillac (Premier Grand Cru Classé)    1990
# ...     ...                                                ...     ...
# 3406  w3406  Saint-Émilion Grand Cru (Premier Grand Cru Cla...    2015
# 3407  w3407                                             Vecina    2013
# 3408  w3408           Montrachet Grand Cru Marquis de Laguiche    2017
# 3409  w3409                               Don PX Pedro Ximenez    1946
# 3410  w3410                            Romanée-Conti Grand Cru    1972
#
#                            winery  avg_ratings  num_ratings    price  \
# 0                            Krug          4.9          135   $7,500
# 1                       Del Dotto          4.9           61  $525.76
# 2                 Château Margaux          4.9           35   $1,695
# 3                 Quinta do Noval          4.9           34   $2,200
# 4                  Château Latour          4.8         1506   $1,695
# ...                           ...          ...          ...      ...
# 3406                Château Pavie          4.8           96  €424,46
# 3407                         Bond          4.8           95     €750
# 3408               Joseph Drouhin          4.8           93     €645
# 3409                  Toro Albalá          4.8           89   €26,78
# 3410  Domaine de La Romanée-Conti          4.8           87   €6.900
#
#                                                   foods
# 0     Pork, Rich fish (salmon, tuna etc), Shellfish,...
# 1     Beef, Lamb, Game (deer, venison), Mature and h...
# 2             Beef, Lamb, Game (deer, venison), Poultry
# 3                          Beef, Mature and hard cheese
# 4             Beef, Lamb, Game (deer, venison), Poultry
# ...                                                 ...
# 3406          Beef, Lamb, Game (deer, venison), Poultry
# 3407          Beef, Lamb, Game (deer, venison), Poultry
# 3408  Pasta, Rich fish (salmon, tuna etc), Shellfish...
# 3409                        Sweet desserts, Blue cheese
# 3410          Beef, Veal, Game (deer, venison), Poultry
#
# [3411 rows x 8 columns]

# %%
'''
     [User Table : user information]

1. uid : user_id
2. name : user_name
3. country : user_country
4. ratings : 해당 유저가 별점을 매긴 리뷰 수
5. follwer : 해당 유저를 팔로우 하는 사람의 수
6. following : 해당 유저가 팔로잉 하는 사람의 수

'''
user
# Out:
#         uid               name country  ratings  follower  following
# 0        u0             Oli G.   Italy     9385      3944        760
# 1        u1  Massimo Trussardi   Italy     9490      5902        421
# 2        u2              Claus   Italy     7104      3474       5000
# 3        u3              Titti   Italy     6591      6544       1155
# 4        u4           Enrico G   Italy     4752      4936        362
# ...     ...                ...     ...      ...       ...        ...
# 2975  u2975        Sarah Vital  France      297        14         12
# 2976  u2976           Hugues M  France      262        60        143
# 2977  u2977     Λανκελοτ Μυνιχ  France      244        41         45
# 2978  u2978              Sarto  France      272        77        177
# 2979  u2979          Пага Пага  France      470        17         13
#
# [2980 rows x 6 columns]

# %%
'''
     [Review Table : wine에 대한 user의 리뷰]

1. uid : user_id
2. wid : wine_id
3. name : user_name
4. wine_name : wine_name
5. wine_vintage : wine_vintage
6. rating : 해당 유저가 와인에 대해 매긴 별점

'''
review
# Out:
#          uid    wid          name                             wine_name  \
# 0         u0  w1293        Oli G.  Bricco dell'Uccellone Barbera d'Asti
# 1         u0  w1072        Oli G.                       Sauvignon Blanc
# 2         u0  w1283        Oli G.                       Sauvignon Blanc
# 3         u0   w997        Oli G.            Amarone della Valpolicella
# 4         u0  w3337        Oli G.                                Barolo
# ...      ...    ...           ...                                   ...
# 15481  u2726  w2203  Robin Berner                            Chardonnay
# 15482  u2726  w3385  Robin Berner                    Cabernet Sauvignon
# 15483  u2726  w2392  Robin Berner                        Cabernet Franc
# 15484  u2728  w3357       Luisa N                    Cabernet Sauvignon
# 15485  u2728  w1072       Luisa N                       Sauvignon Blanc
#
#       wine_vintage  rating
# 0             2017     4.0
# 1             2018     4.0
# 2             2020     4.0
# 3             2016     4.0
# 4             2017     3.0
# ...            ...     ...
# 15481         2017     4.0
# 15482         2015     3.0
# 15483         2012     3.0
# 15484         2018     4.0
# 15485         2018     3.0
#
# [15486 rows x 6 columns]

# %% [markdown]
# # 3. Preprocessing [3점]
# - 결측값 처리와 같은 기본적인 전처리는 이미 해둔 상태임.
# - 중복 데이터에 대한 처리 수행할 것.
# - [중복 데이터] 동일한 유저가 동일한 와인에 대해 별점을 매긴 데이터.

# %% [markdown]
# ## 3-1. 중복 데이터를 확인하고 제거하시오. [1점]

# %% [markdown]
# ###  Q1. 중복된 데이터의 개수 확인 [0.5점]
# - 중복된 데이터가 몇 개인지 출력할 것.
# - [Hint] pandas의 duplicated 함수를 활용할 것.

# %%
# ---- your code ----- #
df=pd.DataFrame(review)
df.duplicated(['uid','wid']).sum()
# Out:
# 2296

# %% [markdown]
# ### Q2. 중복된 데이터 삭제 [0.5점]
# - 이때, 중복된 데이터의 경우 마지막 데이터만 남기고 지울 것.
# - 삭제 후 행의 개수가 13,190개인 것을 확인할 것.

# %%
# ---- your code ----- #
review=df.drop_duplicates(['uid','wid'],keep='last')
# ------- print ------- #
review
# Out:
#          uid    wid          name                             wine_name  \
# 0         u0  w1293        Oli G.  Bricco dell'Uccellone Barbera d'Asti
# 1         u0  w1072        Oli G.                       Sauvignon Blanc
# 2         u0  w1283        Oli G.                       Sauvignon Blanc
# 3         u0   w997        Oli G.            Amarone della Valpolicella
# 4         u0  w3337        Oli G.                                Barolo
# ...      ...    ...           ...                                   ...
# 15481  u2726  w2203  Robin Berner                            Chardonnay
# 15482  u2726  w3385  Robin Berner                    Cabernet Sauvignon
# 15483  u2726  w2392  Robin Berner                        Cabernet Franc
# 15484  u2728  w3357       Luisa N                    Cabernet Sauvignon
# 15485  u2728  w1072       Luisa N                       Sauvignon Blanc
#
#       wine_vintage  rating
# 0             2017     4.0
# 1             2018     4.0
# 2             2020     4.0
# 3             2016     4.0
# 4             2017     3.0
# ...            ...     ...
# 15481         2017     4.0
# 15482         2015     3.0
# 15483         2012     3.0
# 15484         2018     4.0
# 15485         2018     3.0
#
# [13190 rows x 6 columns]

# %%
# reset index
review.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 3-2. 데이터를 분석 목적에 맞게 필터링하시오. [2점]
# - 너무 많은 노드와 엣지가 포함되어 있는 경우 시각화하기 쉽지 않음.
# - 이 경우 데이터 내에서 분석하고자 하는 목적, 강조하고 싶은 부분에 따라 적절히 필터링하여 사용.

# %% [markdown]
# ## [분석 포인트] 어떤 와인이 많은 리뷰를 받았는가?

# %% [markdown]
# - 이번 과제에서는 어떤 와인이 리뷰를 많이 받았는지 강조하여 시각화 해볼 것임.
# - 리뷰를 적게 받은 와인은 적절히 필터링하여, 노드 수를 축소할 것.

# %%
# Wine count : 리뷰에 언급된 와인 수 확인
wine_cnt = review['wid'].value_counts()
wine_cnt
# Out:
# w1283    722
# w2347    592
# w1245    287
# w3357    235
# w1072    218
#         ...
# w3252      1
# w1347      1
# w77        1
# w128       1
# w3008      1
# Name: wid, Length: 1566, dtype: int64

# %%
# 20번 이상의 리뷰를 받은 와인만 골랐을 때, 112개의 와인이 선택됨.
sum(list(wine_cnt >= 20))
# Out:
# 112

# %% [markdown]
# ### Q3. Target wid list 생성 [1점]
# - 20번 이상의 리뷰를 받은 와인의 아이디로 구성된 list를 출력할 것.

# %%
# --- your code --- #
target_wid=[]
condition = (wine_cnt >= 20)
target_wid = wine_cnt.index[condition].to_list()
# ------- print ------- #
target_wid
# Out:
# ['w1283',
#  'w2347',
#  'w1245',
#  'w3357',
#  'w1072',
#  'w1813',
#  'w2417',
#  'w2203',
#  'w3405',
#  'w2917',
#  'w2337',
#  'w2289',
#  'w3389',
#  'w1028',
#  'w1638',
#  'w444',
#  'w997',
#  'w274',
#  'w3347',
#  'w1436',
#  'w937',
#  'w885',
#  'w1354',
#  'w3302',
#  'w1725',
#  'w1627',
#  'w3109',
#  'w3385',
#  'w1295',
#  'w2290',
#  'w2585',
#  'w1958',
#  'w3337',
#  'w3342',
#  'w3188',
#  'w2097',
#  'w2586',
#  'w1921',
#  'w2294',
#  'w2343',
#  'w2929',
#  'w642',
#  'w3184',
#  'w3301',
#  'w2194',
#  'w3234',
#  'w3391',
#  'w1947',
#  'w1934',
#  'w1508',
#  'w2815',
#  'w2776',
#  'w2727',
#  'w2887',
#  'w1252',
#  'w3195',
#  'w2297',
#  'w2794',
#  'w3165',
#  'w282',
#  'w2484',
#  'w1271',
#  'w3336',
#  'w3241',
#  'w2966',
#  'w10',
#  'w2688',
#  'w3382',
#  'w3191',
#  'w2973',
#  'w1254',
#  'w2600',
#  'w2165',
#  'w1488',
#  'w607',
#  'w2164',
#  'w2178',
#  'w2434',
#  'w1378',
#  'w3007',
#  'w3221',
#  'w2252',
#  'w1841',
#  'w2681',
#  'w1932',
#  'w3273',
#  'w2437',
#  'w2902',
#  'w285',
#  'w971',
#  'w2841',
#  'w1256',
#  'w1939',
#  'w3239',
#  'w2231',
#  'w9',
#  'w2813',
#  'w3041',
#  'w2993',
#  'w1301',
#  'w3099',
#  'w647',
#  'w2170',
#  'w657',
#  'w2239',
#  'w2099',
#  'w1984',
#  'w2262',
#  'w1255',
#  'w3187',
#  'w660',
#  'w1748']

# %%
# Result Check: 결과로 112개가 출력되어야 함.
print(len(target_wid))
# Out:
# 112

# %% [markdown]
# ### Q4. Target wid list만 포함한 새로운 데이터셋 생성 [1점]
# - 목표로 하는 wid만 포함한 review 테이블 생성.
# - 이후 새로운 review 테이블 내에 포함된 user와 wine만 포함한 user, wine 테이블 생성.

# %% [markdown]
# ### Filtered Review Table를 생성하시오.

# %%
import pandas as pd
# ----- your code ----- #

df=review
f_review = df[df['wid'].isin(target_wid)]


# ------- print ------- #
f_review
# Out:
#          uid    wid               name                   wine_name  \
# 1         u0  w1072             Oli G.             Sauvignon Blanc
# 2         u0  w1283             Oli G.             Sauvignon Blanc
# 3         u0   w997             Oli G.  Amarone della Valpolicella
# 4         u0  w3337             Oli G.                      Barolo
# 7         u1   w997  Massimo Trussardi  Amarone della Valpolicella
# ...      ...    ...                ...                         ...
# 13184  u2725  w1072      Oliver Sippel             Sauvignon Blanc
# 13185  u2726  w2203       Robin Berner                  Chardonnay
# 13186  u2726  w3385       Robin Berner          Cabernet Sauvignon
# 13188  u2728  w3357            Luisa N          Cabernet Sauvignon
# 13189  u2728  w1072            Luisa N             Sauvignon Blanc
#
#       wine_vintage  rating
# 1             2018     4.0
# 2             2020     4.0
# 3             2016     4.0
# 4             2017     3.0
# 7             2016     3.0
# ...            ...     ...
# 13184         2018     3.0
# 13185         2017     4.0
# 13186         2015     3.0
# 13188         2018     4.0
# 13189         2018     3.0
#
# [8093 rows x 6 columns]

# %% [markdown]
# ### Filtered Wine Table를 생성하시오.

# %%
# target wid
wid_list = list(set(f_review['wid'])) # same target_wid
print(wid_list)
# Out:
# ['w2289', 'w607', 'w2262', 'w2993', 'w3301', 'w3273', 'w1934', 'w2776', 'w1256', 'w1984', 'w2434', 'w3357', 'w3234', 'w3347', 'w2239', 'w1295', 'w885', 'w1283', 'w1354', 'w2688', 'w2417', 'w1921', 'w1252', 'w3239', 'w2600', 'w1028', 'w3187', 'w647', 'w937', 'w3195', 'w1488', 'w1958', 'w274', 'w2973', 'w1271', 'w1254', 'w3165', 'w1301', 'w2813', 'w2178', 'w3007', 'w3382', 'w2294', 'w1072', 'w285', 'w3188', 'w3191', 'w2929', 'w1255', 'w971', 'w2252', 'w3109', 'w2297', 'w3302', 'w2343', 'w2902', 'w3336', 'w1638', 'w642', 'w9', 'w3391', 'w2170', 'w1939', 'w657', 'w3385', 'w3099', 'w2841', 'w3184', 'w2585', 'w3337', 'w1627', 'w282', 'w2290', 'w1378', 'w2727', 'w1748', 'w2586', 'w2203', 'w1841', 'w2097', 'w3389', 'w2917', 'w660', 'w3342', 'w2099', 'w2681', 'w2337', 'w444', 'w2966', 'w2794', 'w3221', 'w1947', 'w1932', 'w10', 'w3241', 'w2231', 'w2165', 'w2347', 'w1245', 'w1436', 'w2437', 'w2194', 'w1725', 'w2484', 'w2164', 'w2887', 'w997', 'w3041', 'w1508', 'w1813', 'w3405', 'w2815']

# %%
# ----- your code ----- #

df=wine
f_wine = df[df['wid'].isin(wid_list)]

# ------- print ------- #
f_wine
# Out:
#         wid                                               name vintage  \
# 9        w9                                          Sauternes    2015
# 10      w10                                          Sauternes    2016
# 274    w274                                             Shiraz    2019
# 282    w282                                         Tignanello    2016
# 285    w285  Initial Blanc de Blancs Brut Champagne Grand C...    N.V.
# ...     ...                                                ...     ...
# 3382  w3382                                 Cabernet Sauvignon    2012
# 3385  w3385                                 Cabernet Sauvignon    2015
# 3389  w3389                                 Cabernet Sauvignon    2016
# 3391  w3391                            Saint-Émilion Grand Cru    2014
# 3405  w3405                                              Tinto    2018
#
#                         winery  avg_ratings  num_ratings      price  \
# 9              Château d'Yquem          4.8          567  $1,384.60
# 10             Château d'Yquem          4.8          534  $1,384.60
# 274               The Standish          4.7           27       $115
# 282                   Antinori          4.6        11270       $120
# 285            Jacques Selosse          4.6         5939       $589
# ...                        ...          ...          ...        ...
# 3382           Screaming Eagle          4.8          224     €5.125
# 3385                 Scarecrow          4.8          209    €848,21
# 3389                 Scarecrow          4.8          162  €2.734,60
# 3391  Château Tertre Roteboeuf          4.8          155       €295
# 3405     Quinta do Monte Xisto          4.8           99     €59,74
#
#                                                   foods
# 9                          Fruity desserts, Blue cheese
# 10                         Fruity desserts, Blue cheese
# 274           Beef, Lamb, Game (deer, venison), Poultry
# 282               Beef, Lamb, Veal, Poultry, Cured Meat
# 285   Pork, Rich fish (salmon, tuna etc), Shellfish,...
# ...                                                 ...
# 3382  Beef, Lamb, Game (deer, venison), Mature and h...
# 3385  Beef, Lamb, Game (deer, venison), Mature and h...
# 3389  Beef, Lamb, Game (deer, venison), Mature and h...
# 3391          Beef, Lamb, Game (deer, venison), Poultry
# 3405            Beef, Pasta, Lamb, Game (deer, venison)
#
# [112 rows x 8 columns]

# %% [markdown]
# ### Filtered User Table을 생성하시오.

# %%
# target uid
uid_list = list(set(f_review['uid']))
print(uid_list)
# Out:
# ['u2720', 'u1000', 'u1594', 'u1430', 'u320', 'u2884', 'u904', 'u2227', 'u2445', 'u1758', 'u770', 'u1690', 'u2915', 'u1911', 'u2842', 'u2518', 'u2657', 'u76', 'u1190', 'u2093', 'u244', 'u2656', 'u1040', 'u579', 'u668', 'u886', 'u1729', 'u2754', 'u1450', 'u1090', 'u2970', 'u2242', 'u2024', 'u1639', 'u1972', 'u2327', 'u239', 'u1470', 'u2834', 'u2102', 'u39', 'u131', 'u1027', 'u2166', 'u1666', 'u2637', 'u368', 'u2858', 'u704', 'u286', 'u154', 'u42', 'u656', 'u1482', 'u148', 'u312', 'u2135', 'u1623', 'u2177', 'u1230', 'u1361', 'u83', 'u1747', 'u2654', 'u1446', 'u338', 'u932', 'u766', 'u1940', 'u1106', 'u532', 'u539', 'u2387', 'u1796', 'u628', 'u709', 'u1048', 'u1652', 'u2243', 'u1508', 'u1097', 'u1876', 'u715', 'u1707', 'u2904', 'u1068', 'u1523', 'u13', 'u2712', 'u2001', 'u1314', 'u927', 'u1569', 'u758', 'u112', 'u1296', 'u2404', 'u2680', 'u784', 'u895', 'u2305', 'u2937', 'u652', 'u866', 'u500', 'u1425', 'u2173', 'u790', 'u1620', 'u1928', 'u1445', 'u2425', 'u373', 'u2872', 'u1122', 'u1862', 'u875', 'u506', 'u434', 'u2577', 'u470', 'u646', 'u199', 'u2788', 'u2419', 'u2459', 'u1213', 'u1645', 'u669', 'u908', 'u2386', 'u2561', 'u2629', 'u1800', 'u1860', 'u2801', 'u1340', 'u2698', 'u2380', 'u1249', 'u1262', 'u2065', 'u948', 'u1810', 'u1851', 'u447', 'u2758', 'u945', 'u694', 'u32', 'u1670', 'u1864', 'u542', 'u1585', 'u557', 'u2210', 'u2363', 'u94', 'u1978', 'u1625', 'u100', 'u1985', 'u2845', 'u2830', 'u2512', 'u1098', 'u696', 'u810', 'u780', 'u1669', 'u1794', 'u395', 'u269', 'u2920', 'u647', 'u219', 'u2157', 'u1312', 'u768', 'u794', 'u2786', 'u2124', 'u759', 'u342', 'u2797', 'u1808', 'u2105', 'u2603', 'u923', 'u1601', 'u2525', 'u536', 'u2867', 'u2536', 'u987', 'u751', 'u1675', 'u2422', 'u1434', 'u503', 'u1084', 'u336', 'u1176', 'u947', 'u1790', 'u93', 'u1766', 'u2691', 'u902', 'u147', 'u207', 'u1792', 'u1473', 'u2237', 'u266', 'u1417', 'u2274', 'u1705', 'u446', 'u1634', 'u2299', 'u160', 'u1276', 'u2296', 'u394', 'u1602', 'u860', 'u2451', 'u442', 'u301', 'u2833', 'u2323', 'u2205', 'u2869', 'u2529', 'u1901', 'u2360', 'u2743', 'u559', 'u1256', 'u2811', 'u1478', 'u38', 'u151', 'u700', 'u438', 'u1558', 'u2247', 'u1591', 'u1079', 'u2565', 'u1358', 'u2233', 'u53', 'u2306', 'u2215', 'u609', 'u519', 'u670', 'u435', 'u2058', 'u876', 'u2097', 'u2555', 'u2075', 'u1007', 'u2241', 'u2461', 'u1382', 'u474', 'u302', 'u473', 'u1943', 'u2655', 'u2583', 'u796', 'u2671', 'u1718', 'u977', 'u283', 'u1143', 'u1245', 'u1267', 'u822', 'u247', 'u444', 'u478', 'u2728', 'u2149', 'u2266', 'u1339', 'u839', 'u1923', 'u2693', 'u1746', 'u429', 'u1520', 'u2890', 'u2521', 'u1743', 'u1055', 'u906', 'u933', 'u1387', 'u1185', 'u1505', 'u1302', 'u1544', 'u2733', 'u809', 'u2044', 'u243', 'u150', 'u71', 'u126', 'u505', 'u2552', 'u981', 'u2649', 'u942', 'u964', 'u1922', 'u2439', 'u1017', 'u762', 'u998', 'u2613', 'u1443', 'u823', 'u2275', 'u2197', 'u1490', 'u2019', 'u1316', 'u2430', 'u68', 'u2576', 'u1401', 'u914', 'u744', 'u2484', 'u250', 'u173', 'u2086', 'u421', 'u2762', 'u120', 'u1413', 'u1217', 'u299', 'u2432', 'u2399', 'u749', 'u2499', 'u2507', 'u1465', 'u179', 'u1963', 'u1131', 'u2668', 'u918', 'u627', 'u1671', 'u287', 'u156', 'u188', 'u2765', 'u2965', 'u1403', 'u820', 'u1782', 'u1493', 'u1748', 'u1872', 'u779', 'u2472', 'u334', 'u1714', 'u2126', 'u2326', 'u1331', 'u123', 'u686', 'u2263', 'u847', 'u1124', 'u464', 'u1637', 'u2704', 'u1188', 'u2611', 'u2311', 'u1060', 'u1681', 'u2398', 'u1150', 'u637', 'u890', 'u672', 'u721', 'u606', 'u2238', 'u2303', 'u489', 'u2938', 'u2664', 'u2331', 'u1817', 'u1745', 'u300', 'u1416', 'u401', 'u1032', 'u466', 'u825', 'u2339', 'u1393', 'u2587', 'u531', 'u2791', 'u2660', 'u645', 'u1466', 'u202', 'u1576', 'u2083', 'u570', 'u181', 'u1609', 'u1762', 'u51', 'u2703', 'u1840', 'u1313', 'u2345', 'u1503', 'u2775', 'u1884', 'u829', 'u28', 'u2236', 'u1016', 'u657', 'u1345', 'u2465', 'u1805', 'u1534', 'u1284', 'u861', 'u1140', 'u1775', 'u1319', 'u767', 'u2929', 'u1458', 'u1513', 'u2212', 'u2699', 'u2344', 'u819', 'u2195', 'u2891', 'u903', 'u880', 'u158 ...

# %%
# ----- your code ----- #


df=user
f_user = df[df['uid'].isin(uid_list)]

# ------- print ------- #
f_user
# Out:
#         uid               name country  ratings  follower  following
# 0        u0             Oli G.   Italy     9385      3944        760
# 1        u1  Massimo Trussardi   Italy     9490      5902        421
# 4        u4           Enrico G   Italy     4752      4936        362
# 5        u5            Arcadio   Italy     2251       692         96
# 13      u13       Pier Ferrari   Italy     1312      1524       1280
# ...     ...                ...     ...      ...       ...        ...
# 2975  u2975        Sarah Vital  France      297        14         12
# 2976  u2976           Hugues M  France      262        60        143
# 2977  u2977     Λανκελοτ Μυνιχ  France      244        41         45
# 2978  u2978              Sarto  France      272        77        177
# 2979  u2979          Пага Пага  France      470        17         13
#
# [2424 rows x 6 columns]

# %% [markdown]
# # 4. Build Graph [4점]
# - 이제 앞서 만든 세 가지 데이터셋을 활용해 그래프를 정의하시오.
# - 그래프는 NetworkX를 바탕으로 정의할 것.
# - 그래프 구성은 다음과 같음.
#     1. Node : Wine, User (Heterogeneous Graph)
#     2. Edge : User-Wine (User가 Wine에 대해 리뷰를 남긴 경우 연결.)
#     3. Edge Type : Undirected

# %%
# Create Undirected Graph
G = nx.Graph()

# %% [markdown]
# ### Q5. 정의한 그래프에 Node를 추가하시오. [2점]
# - wine 노드와 user 노드를 순서대로 추가하시오.
# - 각각의 노드가 어떤 유형의 노드인지 구분하기 위해, node_type이라는 attribute를 추가할 것.
#
# - Wine 노드의 경우 다음과 같이 추가할 것.
#     - Node_id : wid
#     - Attribute : avg_ratings, num_ratings, price, foods, node_type='wine'
#
# - User 노드의 경우 다음과 같이 추가할 것.
#     - Node_id : uid
#     - Attribute : country, ratings, follower, following, node_type='user'

# %% [markdown]
# ### Add wine node [1점]

# %%
# ---- your code ----- #
for index, row in f_wine.iterrows():

    G.add_node(row['wid'],
              avg_ratings=row['avg_ratings'],
              num_ratings=row['num_ratings'],
              price=row["price"],
              foods=row["foods"],
              node_type='wine')

# %%
# Check
for node in G.nodes(data=True):
  print(node)
  break
# Out:
# ('w9', {'avg_ratings': 4.8, 'num_ratings': 567, 'price': '$1,384.60', 'foods': 'Fruity desserts, Blue cheese', 'node_type': 'wine'})

# %% [markdown]
# ### Add user node [1점]

# %%
# ---- your code ----- #
for index, row in f_user.iterrows():
    G.add_node(row['uid'],
              country=row['country'],
              ratings=row['ratings'],
              follower=row["follower"],
              following=row["following"],
              node_type='user')

# %%
# Check
for node in G.nodes(data=True):
  if node[0][0] == 'u':
    print(node)
    break
# Out:
# ('u0', {'country': 'Italy', 'ratings': 9385, 'follower': 3944, 'following': 760, 'node_type': 'user'})

# %% [markdown]
# ### Q6. 정의한 그래프에 Edge를 추가하시오. [1점]
# - 유저가 와인에 대해 리뷰한 경우 두 노드를 연결.
# - 이때, 리뷰의 rating (별점) 값을 weight로 추가해 attribute에 넣을 것.

# %%
# ---- your code ----- #
for index, row in f_review.iterrows():
  G.add_edge(row['wid'], row['uid'], weight=row["rating"])

# %%
# 이 개수가 동일해야 노드와 엣지가 잘 구성된 것입니다! (8093, 2536)
G.number_of_edges(), G.number_of_nodes()
# Out:
# (8093, 2536)

# %% [markdown]
# ### Q7. 정의한 그래프를 저장하시오. [1점]
# - 그래프를 Gephi에서 불러올 수 있도록 저장할 것.
# - [Filename] hw01_graph.graphml

# %%
# ---- your code ----- #
nx.write_graphml_lxml(G, "hw01_graph.graphml")

# %% [markdown]
# # 5. Graph Visualization [3점, 각 질문당 0.5점]
# - Gephi에서 그래프를 시각화 할 것.
# - Graph 파일을 Open하고, Layout 및 속성 설정을 적절히 바꿀 것.
# - 이후, 아래 지시에 따라 그래프 외형을 변경할 것.

# %% [markdown]
# ### Q8. node_type에 따라 서로 다른 색상을 부여하시오.
# - ex) User는 노란색, Wine은 보라색으로 설정.

# %% [markdown]
# ### Q9. Degree에 따라 Node 크기를 조정하시오.
# - Degree가 클수록 노드의 크기가 커지도록 조정할 것.
# - ex) min_size=5, max_size=50으로 설정.

# %% [markdown]
# ### Q10. Node Text 크기를 조정하시오.
# - Degree가 클수록 노드 텍스트의 숫자가 커지도록 조정할 것.
# - ex) min_size=1, max_size=5으로 설정.

# %% [markdown]
# ### Q11. Edge 색상을 조정하시오.
# - Edge Weight에 따라, 낮은 점수(rating)로 연결된 edge와 높은 점수(rating)로 연결된 edge의 색상을 구분할 것.

# %% [markdown]
# ### Q12. 시각화 한 그래프를 보고 가장 리뷰를 많이 받은 두 개의 와인을 찾아, wid를 차례대로 적으시오.

# %% [markdown]
# 답: w1283, w2347

# %% [markdown]
# ### Q13. Gephi에서 제공하는 다양한 옵션을 통해 자유롭게 시각화하시오.
# - 자유롭게 시각화 해보고, 어떤 시도를 해보았는가에 대한 설명을 최소 1가지 적을 것.
# - ex) 어떤 와인이 가장 리뷰를 많이 받았는지 알아보기 위해 Degree에 따라 노드 크기를 조절해보았음.

# %% [markdown]
# 리뷰를 작성한 user를 국가별로 구분해보기 위해 국가별로 uid의 글자 색을 다르게 표시함.

# %% [markdown]
# # Save Graph

# %% [markdown]
# - 자신이 만든 그래프를 이미지 파일로 저장하시오. (캡쳐 권장)
# - png, jpg, jpeg 형식과 같은 이미지 파일로 저장할 것.
# - 아래 셀에 이미지 파일을 붙여넣으세요.

# %% [markdown]
# --- your graph ---

# %% [markdown]
# ![screenshot_143407.png](data:image/png;base64,...)![스크린샷 2023-10-10 오후 2.34.56.png](data:image/png;base64,...)---
